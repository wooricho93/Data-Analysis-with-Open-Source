# %% [markdown]
# <a href="https://colab.research.google.com/github/wooricho93/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)
## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding = 'UTF-8', index = False)

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json', 'w', encoding = 'UTF-8') as f:
    json.dump(data, f, indent = 4, ensure_ascii = False)
## DataFrame을 이용한 저장
df = pd.DataFrame(data)
df.to_json('output_df.json', orient = 'records', indent = 4, force_ascii = False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame([data])

## DataFrame 인덱스 출력
print('index:\n', df.index)
## DataFrame 컬럼 출력
print('\ncolumns:\n', df.columns)
## DataFrame 행 출력
print('\nvalues:\n', df.values.flatten())
## DataFrame 값 출력
print('\nrows:\n', df.values.tolist())
# Out:
# index:
#  RangeIndex(start=0, stop=1, step=1)
#
# columns:
#  Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
#
# values:
#  [list(['김철수', '이영희', '박민수', '최지훈', '정소희']) list([1, 2, 3, 4, 2])
#  list([4.2, 3.8, 4.5, 3.9, 3.5])
#  list(['컴퓨터학', '경영학', '농학', '교육학', '영어영문학'])
#  list(['프로그래밍', '독서토론', '로봇공학', '봉사활동', '음악감상'])]
#
# rows:
#  [[['김철수', '이영희', '박민수', '최지훈', '정소희'], [1, 2, 3, 4, 2], [4.2, 3.8, 4.5, 3.9, 3.5], ['컴퓨터학', '경영학', '농학', '교육학', '영어영문학'], ['프로그래밍', '독서토론', '로봇공학', '봉사활동', '음악감상']]]

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv', encoding = 'UTF-8')
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1)
print(df2)
print(df3)
# Out:
#     이름  학년   학점     학과    동아리
# 0  김철수   1  4.2  컴퓨터공학  프로그래밍
# 1  이영희   2  3.8    경영학   독서토론
# 2  박민수   3  4.5   전자공학   로봇공학
# 3  최지훈   4  3.9     의학   봉사활동
# 4  정소희   2  3.5    심리학   음악감상
#     학번   이름  데이터베이스  파이썬  클라우드
# 0  101  김철수      85   78    92
# 1  102  이영희      76   82    78
# 2  103  박지민      92   95    85
# 3  104  최준서      63   70    75
# 4  105  정미나      88   84    91
#     id name  database  python  cloud
# 0  101  김철수        85      78     92
# 1  102  이영희        76      82     78
# 2  103  박지민        92      95     85
# 3  104  최준서        63      70     75
# 4  105  정미나        88      84     91

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame.from_dict(data, orient = 'index')
## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv', encoding = 'UTF-8', index = False)
df.to_json('students_scores.json', orient = 'records', indent = 4, force_ascii = False)

## HTML 형식으로 저장
html_table = df.to_html()
with open('students_scores.html', 'w', encoding = 'UTF-8') as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"
api_key = '8878e064ed6bd47b24779a3dd675b35321b2d15b08e22f77e631c5e0989f237b'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
if response.status_code == 200:
    print('API 호출 성공')
    print(response.json())
else:
    print(f'API 호출 실패: {response.status_code}')
# Out:
# API 호출 성공
# {'response': {'body': {'totalCount': 40, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '98', 'so2Value': '0.003', 'coValue': '0.5', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '107', 'khaiGrade': '2', 'pm25Value': '46', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.028', 'stationName': '정릉로', 'pm10Grade': '2', 'o3Value': '0.037'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '98', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '112', 'khaiGrade': '2', 'pm25Value': '44', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.016', 'stationName': '도봉구', 'pm10Grade': '2', 'o3Value': '0.054'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '129', 'so2Value': '0.003', 'coValue': '0.7', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '123', 'khaiGrade': '3', 'pm25Value': '46', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.011', 'stationName': '은평구', 'pm10Grade': '3', 'o3Value': '0.053'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '98', 'so2Value': '0.004', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '107', 'khaiGrade': '2', 'pm25Value': '45', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.015', 'stationName': '서대문구', 'pm10Grade': '2', 'o3Value': '0.055'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '96', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '103', 'khaiGrade': '2', 'pm25Value': '43', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.012', 'stationName': '마포구', 'pm10Grade': '2', 'o3Value': '0.059'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '125', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '122', 'khaiGrade': '3', 'pm25Value': '43', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.024', 'stationName': '신촌로', 'pm10Grade': '3', 'o3Value': '0.046'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '110', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '111', 'khaiGrade': '3', 'pm25Value': '32', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.012', 'stationName': '강서구', 'pm10Grade': '3', 'o3Value': '0.055'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '105', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '109', 'khaiGrade': '3', 'pm25Value': '30', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.011', 'stationName': '공항대로', 'pm10Grade': '3', 'o3Value': '0.059'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '123', 'so2Value': '0.002', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '117', 'khaiGrade': '3', 'pm25Value': '47', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '2', 'so2Flag': None, 'dataTime': '2025-11-30 15:00', 'coGrade': '1', 'no2Value': '0.011', 'stationName': '구로구', 'pm10Grade': '3', 'o3Value': '0.052'}, {'so2Grade': '1', 'coFlag': None, 'k ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['response']['body']['items']
df = pd.DataFrame(data)
print(df.head())
# Out:
#   so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag o3Grade  \
# 0        1   None        98    0.003     0.5     None     None       2
# 1        1   None        98    0.003     0.6     None     None       2
# 2        1   None       129    0.003     0.7     None     None       2
# 3        1   None        98    0.004     0.6     None     None       2
# 4        1   None        96    0.003     0.4     None     None       2
#
#   pm10Value khaiGrade  ... no2Grade o3Flag pm25Grade so2Flag  \
# 0       107         2  ...        1   None         2    None
# 1       112         2  ...        1   None         2    None
# 2       123         3  ...        1   None         2    None
# 3       107         2  ...        1   None         2    None
# 4       103         2  ...        1   None         2    None
#
#            dataTime coGrade no2Value stationName pm10Grade o3Value
# 0  2025-11-30 15:00       1    0.028         정릉로         2   0.037
# 1  2025-11-30 15:00       1    0.016         도봉구         2   0.054
# 2  2025-11-30 15:00       1    0.011         은평구         3   0.053
# 3  2025-11-30 15:00       1    0.015        서대문구         2   0.055
# 4  2025-11-30 15:00       1    0.012         마포구         2   0.059
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_csv('air_pollution.csv', index = False, encoding = 'UTF-8')
## EXCEL 형식 데이터 저장
df.to_excel('air_pollution.xlsx', index = False)
## HTML 형식 데이터 저장
df.to_html('air_pollution.html')
